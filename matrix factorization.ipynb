# %%
import pandas as pd
import numpy as np

# %%
movies = pd.read_csv("C:\python\ml-latest-small\\movies.csv")
ratings = pd.read_csv("C:\python\ml-latest-small\\ratings.csv")
ratings.drop(['timestamp'],axis=1,inplace=True)

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings.head()
# Out:
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0
# 2       1        6     4.0
# 3       1       47     5.0
# 4       1       50     5.0

# %%
def replace_name(x):
    return movies[movies['movieId']==x].title.values[0]

ratings.movieId = ratings.movieId.map(replace_name)

# %%
ratings.head()
# Out:
#    userId                      movieId  rating
# 0       1             Toy Story (1995)     4.0
# 1       1      Grumpier Old Men (1995)     4.0
# 2       1                  Heat (1995)     4.0
# 3       1  Seven (a.k.a. Se7en) (1995)     5.0
# 4       1   Usual Suspects, The (1995)     5.0

# %%
M = ratings.pivot_table(index=['userId'],columns=['movieId'],values='rating')

# %%
M.shape
# Out:
# (610, 9719)

# %%
M
# Out:
# movieId  '71 (2014)  'Hellboy': The Seeds of Creation (2004)  \
# userId
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
# 5               NaN                                      NaN
# ...             ...                                      ...
# 606             NaN                                      NaN
# 607             NaN                                      NaN
# 608             NaN                                      NaN
# 609             NaN                                      NaN
# 610             4.0                                      NaN
#
# movieId  'Round Midnight (1986)  'Salem's Lot (2004)  \
# userId
# 1                           NaN                  NaN
# 2                           NaN                  NaN
# ...

# %%
def pearson(s1, s2):
    s1_c = s1 - s1.mean()
    s2_c = s2 - s2.mean()
    return np.sum(s1_c * s2_c)/np.sqrt(np.sum(s1_c ** 2) * np.sum(s2_c ** 2))

# %%
pearson(M['\'burbs, The (1989)'], M['10 Things I Hate About You (1999)'])
# Out:
# 0.1096435895189748

# %%
pearson(M["Harry Potter and the Sorcerer\'s Stone (a.k.a. Harry Potter and the Philosopher\'s Stone) (2001)"],
        M["Harry Potter and the Half-Blood Prince (2009)"])
# Out:
# 0.43261423877936267

# %%
pearson(M['Mission: Impossible II (2000)'], M['Erin Brockovich (2000)'])
# Out:
# 0.06884745969528812

# %%
pearson(M['Clerks (1994)'], M['Mallrats (1995)'])
# Out:
# 0.17026131462587432

# %%
def get_recs(movie_name, M, num):
    
    import numpy as np
    
    reviews = []
    for title in M.columns:
        if title == movie_name:
            continue
        cor = pearson(M[movie_name], M[title])
        if np.isnan(cor):
            continue
        else:
            reviews.append((title, cor))
            
        reviews.sort(key=lambda tup: tup[1], reverse=True)
        return reviews[:num]

# %%
recs = get_recs('Clerks (1994)', M, 10)
# Out:
# c:\users\alin a\opencv\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   after removing the cwd from sys.path.

# %%
recs[:10]
# Out:
# [("'Til There Was You (1997)", 0.0)]

# %%
anti_recs = get_recs('Clerks (1994)', M, 8551)
# Out:
# c:\users\alin a\opencv\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   after removing the cwd from sys.path.

# %%
anti_recs[-10:]
# Out:
# [("'Til There Was You (1997)", 0.0)]
